# %%
# ===================== IMPORTS =====================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from tqdm import tqdm

# ===== ADDED =====
from torchvision.models import inception_v3
from scipy import linalg
import numpy as np
# =================


# ===================== CONFIG ======================
LATENT_DIM = 64
BATCH_SIZE = 128
EPOCHS = 50
LR = 1e-3
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# ===================== VISUALIZATION =====================
def show_reconstructions(model, loader, device, epoch, n=8):
    model.eval()
    with torch.no_grad():
        x, _ = next(iter(loader))
        x = x.to(device)[:n]
        x_hat, _, _ = model(x)

    x = x.cpu()
    x_hat = x_hat.cpu()

    fig, axes = plt.subplots(2, n, figsize=(2*n, 4))
    for i in range(n):
        axes[0, i].imshow(x[i, 0], cmap="gray")
        axes[0, i].axis("off")
        axes[1, i].imshow(x_hat[i, 0], cmap="gray")
        axes[1, i].axis("off")

    axes[0, 0].set_ylabel("Input")
    axes[1, 0].set_ylabel("Recon")
    plt.suptitle(f"Epoch {epoch}")
    plt.show()

# ===================== ENCODER =====================
class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 4, 2, 1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.Conv2d(32, 64, 4, 2, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.Conv2d(64, 128, 4, 2, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 256, 4, 2, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),

            nn.AdaptiveAvgPool2d(1)
        )

        self.fc_mu = nn.Linear(256, latent_dim)
        self.fc_logvar = nn.Linear(256, latent_dim)

    def forward(self, x):
        h = self.conv(x)
        h = h.view(h.size(0), -1)
        mu = self.fc_mu(h)
        logvar = self.fc_logvar(h)
        return mu, logvar

# ===================== DECODER =====================
class Decoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.fc = nn.Linear(latent_dim, 256)

        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, 2, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.ConvTranspose2d(128, 64, 4, 2, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.ConvTranspose2d(64, 32, 4, 2, 1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.ConvTranspose2d(32, 1, 4, 2, 1),
            nn.Sigmoid()
        )

        self.final = nn.ConvTranspose2d(1, 1, 4, 2, 1)

    def forward(self, z):
        h = self.fc(z)
        h = h.view(-1, 256, 1, 1)
        x_hat = self.deconv(h)
        x_hat = self.final(x_hat)
        return torch.sigmoid(x_hat)

# ===================== VAE =====================
class VAE(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.encoder = Encoder(latent_dim)
        self.decoder = Decoder(latent_dim)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, logvar = self.encoder(x)
        z = self.reparameterize(mu, logvar)
        x_hat = self.decoder(z)
        return x_hat, mu, logvar

# ===================== LOSS =====================
def vae_loss(x, x_hat, mu, logvar):
    M = x.size(0)
    recon = F.binary_cross_entropy(x_hat, x, reduction="sum") / M
    kl = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / M
    return recon + kl, recon, kl

# ===================== DATA =====================
transform = transforms.Compose([
    transforms.Resize(32),
    transforms.ToTensor()
])

train_ds = datasets.FashionMNIST(
    root="./data", train=True, download=True, transform=transform
)

loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)

# ===================== TRAIN =====================
model = VAE(LATENT_DIM).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# ===== ADDED: FID + SHARPNESS =====

class InceptionFeatureExtractor(nn.Module):
    def __init__(self, device):
        super().__init__()
        self.net = inception_v3(pretrained=True)
        self.net.fc = nn.Identity()
        self.net.eval().to(device)

    @torch.no_grad()
    def forward(self, x):
        x = x.repeat(1, 3, 1, 1)
        x = F.interpolate(x, size=(299, 299), mode="bilinear", align_corners=False)
        return self.net(x)


def compute_fid(real_feats, fake_feats):
    mu1, mu2 = real_feats.mean(0), fake_feats.mean(0)
    sigma1 = np.cov(real_feats, rowvar=False)
    sigma2 = np.cov(fake_feats, rowvar=False)

    diff = mu1 - mu2
    covmean, _ = linalg.sqrtm(sigma1 @ sigma2, disp=False)
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    return diff @ diff + np.trace(sigma1 + sigma2 - 2 * covmean)


def compute_sharpness(x):
    dx = x[:, :, :, 1:] - x[:, :, :, :-1]
    dy = x[:, :, 1:, :] - x[:, :, :-1, :]
    return (dx.abs().mean() + dy.abs().mean()).item()


fid_extractor = InceptionFeatureExtractor(DEVICE)

# ================================================

for epoch in range(EPOCHS + 1):
    model.train()
    total = 0

    for x, _ in tqdm(loader, desc=f"Epoch {epoch}"):
        x = x.to(DEVICE)

        optimizer.zero_grad()
        x_hat, mu, logvar = model(x)
        loss, recon, kl = vae_loss(x, x_hat, mu, logvar)
        loss.backward()
        optimizer.step()

        total += loss.item()

    # ===== ADDED METRICS =====
    if epoch % 5 == 0:
        model.eval()
        with torch.no_grad():
            x_real, _ = next(iter(loader))
            x_real = x_real.to(DEVICE)[:128]
            x_fake, _, _ = model(x_real)

            real_feats = fid_extractor(x_real).cpu().numpy()
            fake_feats = fid_extractor(x_fake).cpu().numpy()

            fid = compute_fid(real_feats, fake_feats)
            sharp = compute_sharpness(x_fake)

        show_reconstructions(model, loader, DEVICE, epoch)
        print(f"FID: {fid:.2f} | Sharpness: {sharp:.5f}")
    # ========================

    print(f"Epoch {epoch:03d} | Avg Loss {total/len(loader):.4f}")
# Out:
# C:\Users\Mahallakshmi\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Mahallakshmi\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [02:53<00:00,  2.71it/s]
# FID: 196.34 | Sharpness: 0.05150
# Epoch 000 | Avg Loss 558.6099
# Epoch 1: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:54<00:00,  4.10it/s]
# Epoch 001 | Avg Loss 450.6212
# Epoch 2: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:09<00:00,  6.76it/s]
# Epoch 002 | Avg Loss 415.6411
# Epoch 3: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:10<00:00,  6.67it/s]
# Epoch 003 | Avg Loss 392.7548
# Epoch 4: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:11<00:00,  6.53it/s]
# Epoch 004 | Avg Loss 376.5820
# Epoch 5: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:07<00:00,  6.90it/s]
# FID: 120.40 | Sharpness: 0.06777
# Epoch 005 | Avg Loss 365.5249
# Epoch 6: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:05<00:00,  7.19it/s]
# Epoch 006 | Avg Loss 357.4334
# Epoch 7: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:08<00:00,  6.85it/s]
# Epoch 007 | Avg Loss 351.4522
# Epoch 8: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:12<00:00,  6.43it/s]
# Epoch 008 | Avg Loss 347.0366
# Epoch 9: 100%|███████████████████████████████████████████████████████████████████████| 469/469 [01:15<00:00,  6.21it/s]
# Epoch 009 | Avg Loss 343.2597
# Epoch 10: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:10<00:00,  6.67it/s]
# FID: 100.54 | Sharpness: 0.07495
# Epoch 010 | Avg Loss 340.2633
# Epoch 11: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:07<00:00,  6.92it/s]
# Epoch 011 | Avg Loss 337.9297
# Epoch 12: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:05<00:00,  7.11it/s]
# Epoch 012 | Avg Loss 336.0080
# Epoch 13: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:09<00:00,  6.72it/s]
# Epoch 013 | Avg Loss 334.4875
# Epoch 14: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:07<00:00,  6.99it/s]
# Epoch 014 | Avg Loss 333.1777
# Epoch 15: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:17<00:00,  6.07it/s]
# FID: 87.95 | Sharpness: 0.07631
# Epoch 015 | Avg Loss 332.1562
# Epoch 16: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:13<00:00,  6.40it/s]
# Epoch 016 | Avg Loss 331.2989
# Epoch 17: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:06<00:00,  7.10it/s]
# Epoch 017 | Avg Loss 330.6455
# Epoch 18: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:12<00:00,  6.46it/s]
# Epoch 018 | Avg Loss 329.9103
# Epoch 19: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:12<00:00,  6.47it/s]
# Epoch 019 | Avg Loss 329.3872
# Epoch 20: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:08<00:00,  6.87it/s]
# FID: 87.95 | Sharpness: 0.07523
# Epoch 020 | Avg Loss 328.9190
# Epoch 21: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:13<00:00,  6.38it/s]
# Epoch 021 | Avg Loss 328.6463
# Epoch 22: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:22<00:00,  5.72it/s]
# Epoch 022 | Avg Loss 328.2093
# Epoch 23: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:24<00:00,  5.57it/s]
# Epoch 023 | Avg Loss 327.9028
# Epoch 24: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:25<00:00,  5.48it/s]
# Epoch 024 | Avg Loss 327.7081
# Epoch 25: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:18<00:00,  5.95it/s]
# FID: 85.62 | Sharpness: 0.07884
# Epoch 025 | Avg Loss 327.4734
# Epoch 26: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:18<00:00,  5.97it/s]
# Epoch 026 | Avg Loss 327.2664
# Epoch 27: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:21<00:00,  5.79it/s]
# Epoch 027 | Avg Loss 327.0933
# Epoch 28: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:13<00:00,  6.38it/s]
# Epoch 028 | Avg Loss 326.9973
# Epoch 29: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:09<00:00,  6.75it/s]
# Epoch 029 | Avg Loss 326.8042
# Epoch 30: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:11<00:00,  6.54it/s]
# FID: 81.87 | Sharpness: 0.07990
# Epoch 030 | Avg Loss 326.6649
# Epoch 31: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:18<00:00,  5.99it/s]
# Epoch 031 | Avg Loss 326.6165
# Epoch 32: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:21<00:00,  5.77it/s]
# Epoch 032 | Avg Loss 326.4754
# Epoch 33: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:21<00:00,  5.73it/s]
# Epoch 033 | Avg Loss 326.3512
# Epoch 34: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:19<00:00,  5.90it/s]
# Epoch 034 | Avg Loss 326.2700
# Epoch 35: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:15<00:00,  6.18it/s]
# FID: 80.90 | Sharpness: 0.07854
# Epoch 035 | Avg Loss 326.1366
# Epoch 36: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:09<00:00,  6.76it/s]
# Epoch 036 | Avg Loss 326.0736
# Epoch 37: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:20<00:00,  5.84it/s]
# Epoch 037 | Avg Loss 325.9883
# Epoch 38: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:20<00:00,  5.81it/s]
# Epoch 038 | Avg Loss 325.9187
# Epoch 39: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:15<00:00,  6.22it/s]
# Epoch 039 | Avg Loss 325.8223
# Epoch 40: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:25<00:00,  5.52it/s]
# FID: 84.14 | Sharpness: 0.07610
# Epoch 040 | Avg Loss 325.7648
# Epoch 41: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:12<00:00,  6.46it/s]
# Epoch 041 | Avg Loss 325.7569
# Epoch 42: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:09<00:00,  6.77it/s]
# Epoch 042 | Avg Loss 325.6641
# Epoch 43: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:20<00:00,  5.85it/s]
# Epoch 043 | Avg Loss 325.6138
# Epoch 44: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:20<00:00,  5.80it/s]
# Epoch 044 | Avg Loss 325.4962
# Epoch 45: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:16<00:00,  6.10it/s]
# FID: 88.96 | Sharpness: 0.07610
# Epoch 045 | Avg Loss 325.4407
# Epoch 46: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:21<00:00,  5.76it/s]
# Epoch 046 | Avg Loss 325.4258
# Epoch 47: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:18<00:00,  5.99it/s]
# Epoch 047 | Avg Loss 325.3785
# Epoch 48: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:16<00:00,  6.14it/s]
# Epoch 048 | Avg Loss 325.2552
# Epoch 49: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:24<00:00,  5.56it/s]
# Epoch 049 | Avg Loss 325.3203
# Epoch 50: 100%|██████████████████████████████████████████████████████████████████████| 469/469 [01:14<00:00,  6.28it/s]
# FID: 83.89 | Sharpness: 0.07878
# Epoch 050 | Avg Loss 325.1949
